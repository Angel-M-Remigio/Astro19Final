# %%
import matplotlib.pyplot as plt
import numpy as np

random = np.random.uniform(0,1,1000)
length, bins, ignored = plt.hist(random, bins = 100)
plt.xlabel("Occurences")
plt.ylabel("Random Numbers[0-1]")
plt.savefig("Prompt3.pdf", format="pdf")
plt.show()
